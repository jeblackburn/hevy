# %%
import parse_pdf_to_json
from hevy.model import MonthlyWorkoutSchedule
import json
from pathlib import Path

# %%
llm_response = '''
{
  "RoutinesByWeek": {
    "Week 1": {
      "id": "week1_routine1",
      "title": "Week 1 - Routine 1",
      "folder_id": 1,
      "updated_at": "2024-01-01T00:00:00Z",
      "created_at": "2024-01-01T00:00:00Z",
      "exercises": [
        {
          "superset_id": "A",
          "section_type": "superset",
          "rounds": 1,
          "rest_between_rounds": 0,
          "target": "strength",
          "exercises": [
            {
              "exercise_template_id": "79D0BB3A",
              "superset_id": "A",
              "rest_seconds": 0,
              "notes": null,
              "sets": [
                {
                  "index": 0,
                  "type": "normal",
                  "weight_kg": 40,
                  "reps": 10,
                  "rep_range": null,
                  "distance_meters": null,
                  "duration_seconds": null,
                  "rpe": null,
                  "custom_metric": null
                },
                {
                  "index": 1,
                  "type": "normal",
                  "weight_kg": 40,
                  "reps": 10,
                  "rep_range": null,
                  "distance_meters": null,
                  "duration_seconds": null,
                  "rpe": null,
                  "custom_metric": null
                },
                {
                  "index": 2,
                  "type": "normal",
                  "weight_kg": 40,
                  "reps": 10,
                  "rep_range": null,
                  "distance_meters": null,
                  "duration_seconds": null,
                  "rpe": null,
                  "custom_metric": null
                }
              ]
            },
            {
              "exercise_template_id": "55E6546F",
              "superset_id": "A",
              "rest_seconds": 0,
              "notes": null,
              "sets": [
                {
                  "index": 0,
                  "type": "normal",
                  "weight_kg": 20,
                  "reps": 12,
                  "rep_range": null,
                  "distance_meters": null,
                  "duration_seconds": null,
                  "rpe": null,
                  "custom_metric": null
                },
                {
                  "index": 1,
                  "type": "normal",
                  "weight_kg": 20,
                  "reps": 12,
                  "rep_range": null,
                  "distance_meters": null,
                  "duration_seconds": null,
                  "rpe": null,
                  "custom_metric": null
                },
                {
                  "index": 2,
                  "type": "normal",
                  "weight_kg": 20,
                  "reps": 12,
                  "rep_range": null,
                  "distance_meters": null,
                  "duration_seconds": null,
                  "rpe": null,
                  "custom_metric": null
                }
              ]
            },
            {
              "exercise_template_id": "A5AC6449",
              "superset_id": "A",
              "rest_seconds": 90,
              "notes": null,
              "sets": [
                {
                  "index": 0,
                  "type": "normal",
                  "weight_kg": 15,
                  "reps": 15,
                  "rep_range": null,
                  "distance_meters": null,
                  "duration_seconds": null,
                  "rpe": null,
                  "custom_metric": null
                },
                {
                  "index": 1,
                  "type": "normal",
                  "weight_kg": 15,
                  "reps": 15,
                  "rep_range": null,
                  "distance_meters": null,
                  "duration_seconds": null,
                  "rpe": null,
                  "custom_metric": null
                },
                {
                  "index": 2,
                  "type": "normal",
                  "weight_kg": 15,
                  "reps": 15,
                  "rep_range": null,
                  "distance_meters": null,
                  "duration_seconds": null,
                  "rpe": null,
                  "custom_metric": null
                }
              ]
            }
          ]
        },
        {
          "superset_id": "B",
          "section_type": "superset",
          "rounds": 1,
          "rest_between_rounds": 0,
          "target": "strength",
          "exercises": [
            {
              "exercise_template_id": "B5D3A742",
              "superset_id": "B",
              "rest_seconds": 0,
              "notes": null,
              "sets": [
                {
                  "index": 0,
                  "type": "normal",
                  "weight_kg": 0,
                  "reps": 12,
                  "rep_range": null,
                  "distance_meters": null,
                  "duration_seconds": null,
                  "rpe": null,
                  "custom_metric": null
                },
                {
                  "index": 1,
                  "type": "normal",
                  "weight_kg": 0,
                  "reps": 12,
                  "rep_range": null,
                  "distance_meters": null,
                  "duration_seconds": null,
                  "rpe": null,
                  "custom_metric": null
                },
                {
                  "index": 2,
                  "type": "normal",
                  "weight_kg": 0,
                  "reps": 12,
                  "rep_range": null,
                  "distance_meters": null,
                  "duration_seconds": null,
                  "rpe": null,
                  "custom_metric": null
                }
              ]
            },
            {
              "exercise_template_id": "4F5866F8",
              "superset_id": "B",
              "rest_seconds": 0,
              "notes": null,
              "sets": [
                {
                  "index": 0,
                  "type": "normal",
                  "weight_kg": 0,
                  "reps": 15,
                  "rep_range": null,
                  "distance_meters": null,
                  "duration_seconds": null,
                  "rpe": null,
                  "custom_metric": null
                },
                {
                  "index": 1,
                  "type": "normal",
                  "weight_kg": 0,
                  "reps": 15,
                  "rep_range": null,
                  "distance_meters": null,
                  "duration_seconds": null,
                  "rpe": null,
                  "custom_metric": null
                },
                {
                  "index": 2,
                  "type": "normal",
                  "weight_kg": 0,
                  "reps": 15,
                  "rep_range": null,
                  "distance_meters": null,
                  "duration_seconds": null,
                  "rpe": null,
                  "custom_metric": null
                }
              ]
            },
            {
              "exercise_template_id": "A41C7261",
              "superset_id": "B",
              "rest_seconds": 90,
              "notes": null,
              "sets": [
                {
                  "index": 0,
                  "type": "normal",
                  "weight_kg": 0,
                  "reps": 20,
                  "rep_range": null,
                  "distance_meters": null,
                  "duration_seconds": null,
                  "rpe": null,
                  "custom_metric": null
                },
                {
                  "index": 1,
                  "type": "normal",
                  "weight_kg": 0,
                  "reps": 20,
                  "rep_range": null,
                  "distance_meters": null,
                  "duration_seconds": null,
                  "rpe": null,
                  "custom_metric": null
                },
                {
                  "index": 2,
                  "type": "normal",
                  "weight_kg": 0,
                  "reps": 20,
                  "rep_range": null,
                  "distance_meters": null,
                  "duration_seconds": null,
                  "rpe": null,
                  "custom_metric": null
                }
              ]
            }
          ]
        },
        {
          "superset_id": "C",
          "section_type": "superset",
          "rounds": 1,
          "rest_between_rounds": 0,
          "target": "strength",
          "exercises": [
            {
              "exercise_template_id": "3601968B",
              "superset_id": "C",
              "rest_seconds": 0,
              "notes": null,
              "sets": [
                {
                  "index": 0,
                  "type": "normal",
                  "weight_kg": 20,
                  "reps": 12,
                  "rep_range": null,
                  "distance_meters": null,
                  "duration_seconds": null,
                  "rpe": null,
                  "custom_metric": null
                },
                {
                  "index": 1,
                  "type": "normal",
                  "weight_kg": 20,
                  "reps": 12,
                  "rep_range": null,
                  "distance_meters": null,
                  "duration_seconds": null,
                  "rpe": null,
                  "custom_metric": null
                },
                {
                  "index": 2,
                  "type": "normal",
                  "weight_kg": 20,
                  "reps": 12,
                  "rep_range": null,
                  "distance_meters": null,
                  "duration_seconds": null,
                  "rpe": null,
                  "custom_metric": null
                }
              ]
            },
            {
              "exercise_template_id": "37FCC2BB",
              "superset_id": "C",
              "rest_seconds": 0,
              "notes": null,
              "sets": [
                {
                  "index": 0,
                  "type": "normal",
                  "weight_kg": 10,
                  "reps": 15,
                  "rep_range": null,
                  "distance_meters": null,
                  "duration_seconds": null,
                  "rpe": null,
                  "custom_metric": null
                },
                {
                  "index": 1,
                  "type": "normal",
                  "weight_kg": 10,
                  "reps": 15,
                  "rep_range": null,
                  "distance_meters": null,
                  "duration_seconds": null,
                  "rpe": null,
                  "custom_metric": null
                },
                {
                  "index": 2,
                  "type": "normal",
                  "weight_kg": 10,
                  "reps": 15,
                  "rep_range": null,
                  "distance_meters": null,
                  "duration_seconds": null,
                  "rpe": null,
                  "custom_metric": null
                }
              ]
            },
            {
              "exercise_template_id": "BB792A36",
              "superset_id": "C",
              "rest_seconds": 90,
              "notes": null,
              "sets": [
                {
                  "index": 0,
                  "type": "normal",
                  "weight_kg": 0,
                  "reps": 10,
                  "rep_range": null,
                  "distance_meters": null,
                  "duration_seconds": null,
                  "rpe": null,
                  "custom_metric": null
                },
                {
                  "index": 1,
                  "type": "normal",
                  "weight_kg": 0,
                  "reps": 10,
                  "rep_range": null,
                  "distance_meters": null,
                  "duration_seconds": null,
                  "rpe": null,
                  "custom_metric": null
                },
                {
                  "index": 2,
                  "type": "normal",
                  "weight_kg": 0,
                  "reps": 10,
                  "rep_range": null,
                  "distance_meters": null,
                  "duration_seconds": null,
                  "rpe": null,
                  "custom_metric": null
                }
              ]
            }
          ]
        }
      ]
    },
    "Week 2": {
      "id": "week2_routine1",
      "title": "Week 2 - Routine 1",
      "folder_id": 2,
      "updated_at": "2024-01-08T00:00:00Z",
      "created_at": "2024-01-08T00:00:00Z",
      "exercises": [
        {
          "superset_id": "A",
          "section_type": "superset",
          "rounds": 1,
          "rest_between_rounds": 0,
          "target": "strength",
          "exercises": [
            {
              "exercise_template_id": "79D0BB3A",
              "superset_id": "A",
              "rest_seconds": 0,
              "notes": null,
              "sets": [
                {
                  "index": 0,
                  "type": "normal",
                  "weight_kg": 40,
                  "reps": 10,
                  "rep_range": null,
                  "distance_meters": null,
                  "duration_seconds": null,
                  "rpe": null,
                  "custom_metric": null
                },
                {
                  "index": 1,
                  "type": "normal",
                  "weight_kg": 40,
                  "reps": 10,
                  "rep_range": null,
                  "distance_meters": null,
                  "duration_seconds": null,
                  "rpe": null,
                  "custom_metric": null
                },
                {
                  "index": 2,
                  "type": "normal",
                  "weight_kg": 40,
                  "reps": 10,
                  "rep_range": null,
                  "distance_meters": null,
                  "duration_seconds": null,
                  "rpe": null,
                  "custom_metric": null
                }
              ]
            },
            {
              "exercise_template_id": "55E6546F",
              "superset_id": "A",
              "rest_seconds": 0,
              "notes": null,
              "sets": [
                {
                  "index": 0,
                  "type": "normal",
                  "weight_kg": 20,
                  "reps": 12,
                  "rep_range": null,
                  "distance_meters": null,
                  "duration_seconds": null,
                  "rpe": null,
                  "custom_metric": null
                },
                {
                  "index": 1,
                  "type": "normal",
                  "weight_kg": 20,
                  "reps": 12,
                  "rep_range": null,
                  "distance_meters": null,
                  "duration_seconds": null,
                  "rpe": null,
                  "custom_metric": null
                },
                {
                  "index": 2,
                  "type": "normal",
                  "weight_kg": 20,
                  "reps": 12,
                  "rep_range": null,
                  "distance_meters": null,
                  "duration_seconds": null,
                  "rpe": null,
                  "custom_metric": null
                }
              ]
            },
            {
              "exercise_template_id": "A5AC6449",
              "superset_id": "A",
              "rest_seconds": 90,
              "notes": null,
              "sets": [
                {
                  "index": 0,
                  "type": "normal",
                  "weight_kg": 15,
                  "reps": 15,
                  "rep_range": null,
                  "distance_meters": null,
                  "duration_seconds": null,
                  "rpe": null,
                  "custom_metric": null
                },
                {
                  "index": 1,
                  "type": "normal",
                  "weight_kg": 15,
                  "reps": 15,
                  "rep_range": null,
                  "distance_meters": null,
                  "duration_seconds": null,
                  "rpe": null,
                  "custom_metric": null
                },
                {
                  "index": 2,
                  "type": "normal",
                  "weight_kg": 15,
                  "reps": 15,
                  "rep_range": null,
                  "distance_meters": null,
                  "duration_seconds": null,
                  "rpe": null,
                  "custom_metric": null
                }
              ]
            }
          ]
        },
        {
          "superset_id": "B",
          "section_type": "superset",
          "rounds": 1,
          "rest_between_rounds": 0,
          "target": "strength",
          "exercises": [
            {
              "exercise_template_id": "B5D3A742",
              "superset_id": "B",
              "rest_seconds": 0,
              "notes": null,
              "sets": [
                {
                  "index": 0,
                  "type": "normal",
                  "weight_kg": 0,
                  "reps": 12,
                  "rep_range": null,
                  "distance_meters": null,
                  "duration_seconds": null,
                  "rpe": null,
                  "custom_metric": null
                },
                {
                  "index": 1,
                  "type": "normal",
                  "weight_kg": 0,
                  "reps": 12,
                  "rep_range": null,
                  "distance_meters": null,
                  "duration_seconds": null,
                  "rpe": null,
                  "custom_metric": null
                },
                {
                  "index": 2,
                  "type": "normal",
                  "weight_kg": 0,
                  "reps": 12,
                  "rep_range": null,
                  "distance_meters": null,
                  "duration_seconds": null,
                  "rpe": null,
                  "custom_metric": null
                }
              ]
            },
            {
              "exercise_template_id": "4F5866F8",
              "superset_id": "B",
              "rest_seconds": 0,
              "notes": null,
              "sets": [
                {
                  "index": 0,
                  "type": "normal",
                  "weight_kg": 0,
                  "reps": 15,
                  "rep_range": null,
                  "distance_meters": null,
                  "duration_seconds": null,
                  "rpe": null,
                  "custom_metric": null
                },
                {
                  "index": 1,
                  "type": "normal",
                  "weight_kg": 0,
                  "reps": 15,
                  "rep_range": null,
                  "distance_meters": null,
                  "duration_seconds": null,
                  "rpe": null,
                  "custom_metric": null
                },
                {
                  "index": 2,
                  "type": "normal",
                  "weight_kg": 0,
                  "reps": 15,
                  "rep_range": null,
                  "distance_meters": null,
                  "duration_seconds": null,
                  "rpe": null,
                  "custom_metric": null
                }
              ]
            },
            {
              "exercise_template_id": "A41C7261",
              "superset_id": "B",
              "rest_seconds": 90,
              "notes": null,
              "sets": [
                {
                  "index": 0,
                  "type": "normal",
                  "weight_kg": 0,
                  "reps": 20,
                  "rep_range": null,
                  "distance_meters": null,
                  "duration_seconds": null,
                  "rpe": null,
                  "custom_metric": null
                },
                {
                  "index": 1,
                  "type": "normal",
                  "weight_kg": 0,
                  "reps": 20,
                  "rep_range": null,
                  "distance_meters": null,
                  "duration_seconds": null,
                  "rpe": null,
                  "custom_metric": null
                },
                {
                  "index": 2,
                  "type": "normal",
                  "weight_kg": 0,
                  "reps": 20,
                  "rep_range": null,
                  "distance_meters": null,
                  "duration_seconds": null,
                  "rpe": null,
                  "custom_metric": null
                }
              ]
            }
          ]
        },
        {
          "superset_id": "C",
          "section_type": "superset",
          "rounds": 1,
          "rest_between_rounds": 0,
          "target": "strength",
          "exercises": [
            {
              "exercise_template_id": "3601968B",
              "superset_id": "C",
              "rest_seconds": 0,
              "notes": null,
              "sets": [
                {
                  "index": 0,
                  "type": "normal",
                  "weight_kg": 20,
                  "reps": 12,
                  "rep_range": null,
                  "distance_meters": null,
                  "duration_seconds": null,
                  "rpe": null,
                  "custom_metric": null
                },
                {
                  "index": 1,
                  "type": "normal",
                  "weight_kg": 20,
                  "reps": 12,
                  "rep_range": null,
                  "distance_meters": null,
                  "duration_seconds": null,
                  "rpe": null,
                  "custom_metric": null
                },
                {
                  "index": 2,
                  "type": "normal",
                  "weight_kg": 20,
                  "reps": 12,
                  "rep_range": null,
                  "distance_meters": null,
                  "duration_seconds": null,
                  "rpe": null,
                  "custom_metric": null
                }
              ]
            },
            {
              "exercise_template_id": "37FCC2BB",
              "superset_id": "C",
              "rest_seconds": 0,
              "notes": null,
              "sets": [
                {
                  "index": 0,
                  "type": "normal",
                  "weight_kg": 10,
                  "reps": 15,
                  "rep_range": null,
                  "distance_meters": null,
                  "duration_seconds": null,
                  "rpe": null,
                  "custom_metric": null
                },
                {
                  "index": 1,
                  "type": "normal",
                  "weight_kg": 10,
                  "reps": 15,
                  "rep_range": null,
                  "distance_meters": null,
                  "duration_seconds": null,
                  "rpe": null,
                  "custom_metric": null
                },
                {
                  "index": 2,
                  "type": "normal",
                  "weight_kg": 10,
                  "reps": 15,
                  "rep_range": null,
                  "distance_meters": null,
                  "duration_seconds": null,
                  "rpe": null,
                  "custom_metric": null
                }
              ]
            },
            {
              "exercise_template_id": "BB792A36",
              "superset_id": "C",
              "rest_seconds": 90,
              "notes": null,
              "sets": [
                {
                  "index": 0,
                  "type": "normal",
                  "weight_kg": 0,
                  "reps": 10,
                  "rep_range": null,
                  "distance_meters": null,
                  "duration_seconds": null,
                  "rpe": null,
                  "custom_metric": null
                },
                {
                  "index": 1,
                  "type": "normal",
                  "weight_kg": 0,
                  "reps": 10,
                  "rep_range": null,
                  "distance_meters": null,
                  "duration_seconds": null,
                  "rpe": null,
                  "custom_metric": null
                },
                {
                  "index": 2,
                  "type": "normal",
                  "weight_kg": 0,
                  "reps": 10,
                  "rep_range": null,
                  "distance_meters": null,
                  "duration_seconds": null,
                  "rpe": null,
                  "custom_metric": null
                }
              ]
            }
          ]
        }
      ]
    },
    "Week 3": {
      "id": "week3_routine1",
      "title": "Week 3 - Routine 1",
      "folder_id": 3,
      "updated_at": "2024-01-15T00:00:00Z",
      "created_at": "2024-01-15T00:00:00Z",
      "exercises": [
        {
          "superset_id": "A",
          "section_type": "superset",
          "rounds": 1,
          "rest_between_rounds": 0,
          "target": "strength",
          "exercises": [
            {
              "exercise_template_id": "79D0BB3A",
              "superset_id": "A",
              "rest_seconds": 0,
              "notes": null,
              "sets": [
                {
                  "index": 0,
                  "type": "normal",
                  "weight_kg": 40,
                  "reps": 10,
                  "rep_range": null,
                  "distance_meters": null,
                  "duration_seconds": null,
                  "rpe": null,
                  "custom_metric": null
                },
                {
                  "index": 1,
                  "type": "normal",
                  "weight_kg": 40,
                  "reps": 10,
                  "rep_range": null,
                  "distance_meters": null,
                  "duration_seconds": null,
                  "rpe": null,
                  "custom_metric": null
                },
                {
                  "index": 2,
                  "type": "normal",
                  "weight_kg": 40,
                  "reps": 10,
                  "rep_range": null,
                  "distance_meters": null,
                  "duration_seconds": null,
                  "rpe": null,
                  "custom_metric": null
                }
              ]
            },
            {
              "exercise_template_id": "55E6546F",
              "superset_id": "A",
              "rest_seconds": 0,
              "notes": null,
              "sets": [
                {
                  "index": 0,
                  "type": "normal",
                  "weight_kg": 20,
                  "reps": 12,
                  "rep_range": null,
                  "distance_meters": null,
                  "duration_seconds": null,
                  "rpe": null,
                  "custom_metric": null
                },
                {
                  "index": 1,
                  "type": "normal",
                  "weight_kg": 20,
                  "reps": 12,
                  "rep_range": null,
                  "distance_meters": null,
                  "duration_seconds": null,
                  "rpe": null,
                  "custom_metric": null
                },
                {
                  "index": 2,
                  "type": "normal",
                  "weight_kg": 20,
                  "reps": 12,
                  "rep_range": null,
                  "distance_meters": null,
                  "duration_seconds": null,
                  "rpe": null,
                  "custom_metric": null
                }
              ]
            },
            {
              "exercise_template_id": "A5AC6449",
              "superset_id": "A",
              "rest_seconds": 90,
              "notes": null,
              "sets": [
                {
                  "index": 0,
                  "type": "normal",
                  "weight_kg": 15,
                  "reps": 15,
                  "rep_range": null,
                  "distance_meters": null,
                  "duration_seconds": null,
                  "rpe": null,
                  "custom_metric": null
                },
                {
                  "index": 1,
                  "type": "normal",
                  "weight_kg": 15,
                  "reps": 15,
                  "rep_range": null,
                  "distance_meters": null,
                  "duration_seconds": null,
                  "rpe": null,
                  "custom_metric": null
                },
                {
                  "index": 2,
                  "type": "normal",
                  "weight_kg": 15,
                  "reps": 15,
                  "rep_range": null,
                  "distance_meters": null,
                  "duration_seconds": null,
                  "rpe": null,
                  "custom_metric": null
                }
              ]
            }
          ]
        },
        {
          "superset_id": "B",
          "section_type": "superset",
          "rounds": 1,
          "rest_between_rounds": 0,
          "target": "strength",
          "exercises": [
            {
              "exercise_template_id": "B5D3A742",
              "superset_id": "B",
              "rest_seconds": 0,
              "notes": null,
              "sets": [
                {
                  "index": 0,
                  "type": "normal",
                  "weight_kg": 0,
                  "reps": 12,
                  "rep_range": null,
                  "distance_meters": null,
                  "duration_seconds": null,
                  "rpe": null,
                  "custom_metric": null
                },
                {
                  "index": 1,
                  "type": "normal",
                  "weight_kg": 0,
                  "reps": 12,
                  "rep_range": null,
                  "distance_meters": null,
                  "duration_seconds": null,
                  "rpe": null,
                  "custom_metric": null
                },
                {
                  "index": 2,
                  "type": "normal",
                  "weight_kg": 0,
                  "reps": 12,
                  "rep_range": null,
                  "distance_meters": null,
                  "duration_seconds": null,
                  "rpe": null,
                  "custom_metric": null
                }
              ]
            },
            {
              "exercise_template_id": "4F5866F8",
              "superset_id": "B",
              "rest_seconds": 0,
              "notes": null,
              "sets": [
                {
                  "index": 0,
                  "type": "normal",
                  "weight_kg": 0,
                  "reps": 15,
                  "rep_range": null,
                  "distance_meters": null,
                  "duration_seconds": null,
                  "rpe": null,
                  "custom_metric": null
                },
                {
                  "index": 1,
                  "type": "normal",
                  "weight_kg": 0,
                  "reps": 15,
                  "rep_range": null,
                  "distance_meters": null,
                  "duration_seconds": null,
                  "rpe": null,
                  "custom_metric": null
                },
                {
                  "index": 2,
                  "type": "normal",
                  "weight_kg": 0,
                  "reps": 15,
                  "rep_range": null,
                  "distance_meters": null,
                  "duration_seconds": null,
                  "rpe": null,
                  "custom_metric": null
                }
              ]
            },
            {
              "exercise_template_id": "A41C7261",
              "superset_id": "B",
              "rest_seconds": 90,
              "notes": null,
              "sets": [
                {
                  "index": 0,
                  "type": "normal",
                  "weight_kg": 0,
                  "reps": 20,
                  "rep_range": null,
                  "distance_meters": null,
                  "duration_seconds": null,
                  "rpe": null,
                  "custom_metric": null
                },
                {
                  "index": 1,
                  "type": "normal",
                  "weight_kg": 0,
                  "reps": 20,
                  "rep_range": null,
                  "distance_meters": null,
                  "duration_seconds": null,
                  "rpe": null,
                  "custom_metric": null
                },
                {
                  "index": 2,
                  "type": "normal",
                  "weight_kg": 0,
                  "reps": 20,
                  "rep_range": null,
                  "distance_meters": null,
                  "duration_seconds": null,
                  "rpe": null,
                  "custom_metric": null
                }
              ]
            }
          ]
        },
        {
          "superset_id": "C",
          "section_type": "superset",
          "rounds": 1,
          "rest_between_rounds": 0,
          "target": "strength",
          "exercises": [
            {
              "exercise_template_id": "3601968B",
              "superset_id": "C",
              "rest_seconds": 0,
              "notes": null,
              "sets": [
                {
                  "index": 0,
                  "type": "normal",
                  "weight_kg": 20,
                  "reps": 12,
                  "rep_range": null,
                  "distance_meters": null,
                  "duration_seconds": null,
                  "rpe": null,
                  "custom_metric": null
                },
                {
                  "index": 1,
                  "type": "normal",
                  "weight_kg": 20,
                  "reps": 12,
                  "rep_range": null,
                  "distance_meters": null,
                  "duration_seconds": null,
                  "rpe": null,
                  "custom_metric": null
                },
                {
                  "index": 2,
                  "type": "normal",
                  "weight_kg": 20,
                  "reps": 12,
                  "rep_range": null,
                  "distance_meters": null,
                  "duration_seconds": null,
                  "rpe": null,
                  "custom_metric": null
                }
              ]
            },
            {
              "exercise_template_id": "37FCC2BB",
              "superset_id": "C",
              "rest_seconds": 0,
              "notes": null,
              "sets": [
                {
                  "index": 0,
                  "type": "normal",
                  "weight_kg": 10,
                  "reps": 15,
                  "rep_range": null,
                  "distance_meters": null,
                  "duration_seconds": null,
                  "rpe": null,
                  "custom_metric": null
                },
                {
                  "index": 1,
                  "type": "normal",
                  "weight_kg": 10,
                  "reps": 15,
                  "rep_range": null,
                  "distance_meters": null,
                  "duration_seconds": null,
                  "rpe": null,
                  "custom_metric": null
                },
                {
                  "index": 2,
                  "type": "normal",
                  "weight_kg": 10,
                  "reps": 15,
                  "rep_range": null,
                  "distance_meters": null,
                  "duration_seconds": null,
                  "rpe": null,
                  "custom_metric": null
                }
              ]
            },
            {
              "exercise_template_id": "BB792A36",
              "superset_id": "C",
              "rest_seconds": 90,
              "notes": null,
              "sets": [
                {
                  "index": 0,
                  "type": "normal",
                  "weight_kg": 0,
                  "reps": 10,
                  "rep_range": null,
                  "distance_meters": null,
                  "duration_seconds": null,
                  "rpe": null,
                  "custom_metric": null
                },
                {
                  "index": 1,
                  "type": "normal",
                  "weight_kg": 0,
                  "reps": 10,
                  "rep_range": null,
                  "distance_meters": null,
                  "duration_seconds": null,
                  "rpe": null,
                  "custom_metric": null
                },
                {
                  "index": 2,
                  "type": "normal",
                  "weight_kg": 0,
                  "reps": 10,
                  "rep_range": null,
                  "distance_meters": null,
                  "duration_seconds": null,
                  "rpe": null,
                  "custom_metric": null
                }
              ]
            }
          ]
        }
      ]
    },
    "Week 4": {
      "id": "week4_routine1",
      "title": "Week 4 - Routine 1",
      "folder_id": 4,
      "updated_at": "2024-01-22T00:00:00Z",
      "created_at": "2024-01-22T00:00:00Z",
      "exercises": [
        {
          "superset_id": "A",
          "section_type": "superset",
          "rounds": 1,
          "rest_between_rounds": 0,
          "target": "strength",
          "exercises": [
            {
              "exercise_template_id": "79D0BB3A",
              "superset_id": "A",
              "rest_seconds": 0,
              "notes": null,
              "sets": [
                {
                  "index": 0,
                  "type": "normal",
                  "weight_kg": 40,
                  "reps": 10,
                  "rep_range": null,
                  "distance_meters": null,
                  "duration_seconds": null,
                  "rpe": null,
                  "custom_metric": null
                },
                {
                  "index": 1,
                  "type": "normal",
                  "weight_kg": 40,
                  "reps": 10,
                  "rep_range": null,
                  "distance_meters": null,
                  "duration_seconds": null,
                  "rpe": null,
                  "custom_metric": null
                },
                {
                  "index": 2,
                  "type": "normal",
                  "weight_kg": 40,
                  "reps": 10,
                  "rep_range": null,
                  "distance_meters": null,
                  "duration_seconds": null,
                  "rpe": null,
                  "custom_metric": null
                }
              ]
            },
            {
              "exercise_template_id": "55E6546F",
              "superset_id": "A",
              "rest_seconds": 0,
              "notes": null,
              "sets": [
                {
                  "index": 0,
                  "type": "normal",
                  "weight_kg": 20,
                  "reps": 12,
                  "rep_range": null,
                  "distance_meters": null,
                  "duration_seconds": null,
                  "rpe": null,
                  "custom_metric": null
                },
                {
                  "index": 1,
                  "type": "normal",
                  "weight_kg": 20,
                  "reps": 12,
                  "rep_range": null,
                  "distance_meters": null,
                  "duration_seconds": null,
                  "rpe": null,
                  "custom_metric": null
                },
                {
                  "index": 2,
                  "type": "normal",
                  "weight_kg": 20,
                  "reps": 12,
                  "rep_range": null,
                  "distance_meters": null,
                  "duration_seconds": null,
                  "rpe": null,
                  "custom_metric": null
                }
              ]
            },
            {
              "exercise_template_id": "A5AC6449",
              "superset_id": "A",
              "rest_seconds": 90,
              "notes": null,
              "sets": [
                {
                  "index": 0,
                  "type": "normal",
                  "weight_kg": 15,
                  "reps": 15,
                  "rep_range": null,
                  "distance_meters": null,
                  "duration_seconds": null,
                  "rpe": null,
                  "custom_metric": null
                },
                {
                  "index": 1,
                  "type": "normal",
                  "weight_kg": 15,
                  "reps": 15,
                  "rep_range": null,
                  "distance_meters": null,
                  "duration_seconds": null,
                  "rpe": null,
                  "custom_metric": null
                },
                {
                  "index": 2,
                  "type": "normal",
                  "weight_kg": 15,
                  "reps": 15,
                  "rep_range": null,
                  "distance_meters": null,
                  "duration_seconds": null,
                  "rpe": null,
                  "custom_metric": null
                }
              ]
            }
          ]
        },
        {
          "superset_id": "B",
          "section_type": "superset",
          "rounds": 1,
          "rest_between_rounds": 0,
          "target": "strength",
          "exercises": [
            {
              "exercise_template_id": "B5D3A742",
              "superset_id": "B",
              "rest_seconds": 0,
              "notes": null,
              "sets": [
                {
                  "index": 0,
                  "type": "normal",
                  "weight_kg": 0,
                  "reps": 12,
                  "rep_range": null,
                  "distance_meters": null,
                  "duration_seconds": null,
                  "rpe": null,
                  "custom_metric": null
                },
                {
                  "index": 1,
                  "type": "normal",
                  "weight_kg": 0,
                  "reps": 12,
                  "rep_range": null,
                  "distance_meters": null,
                  "duration_seconds": null,
                  "rpe": null,
                  "custom_metric": null
                },
                {
                  "index": 2,
                  "type": "normal",
                  "weight_kg": 0,
                  "reps": 12,
                  "rep_range": null,
                  "distance_meters": null,
                  "duration_seconds": null,
                  "rpe": null,
                  "custom_metric": null
                }
              ]
            },
            {
              "exercise_template_id": "4F5866F8",
              "superset_id": "B",
              "rest_seconds": 0,
              "notes": null,
              "sets": [
                {
                  "index": 0,
                  "type": "normal",
                  "weight_kg": 0,
                  "reps": 15,
                  "rep_range": null,
                  "distance_meters": null,
                  "duration_seconds": null,
                  "rpe": null,
                  "custom_metric": null
                },
                {
                  "index": 1,
                  "type": "normal",
                  "weight_kg": 0,
                  "reps": 15,
                  "rep_range": null,
                  "distance_meters": null,
                  "duration_seconds": null,
                  "rpe": null,
                  "custom_metric": null
                },
                {
                  "index": 2,
                  "type": "normal",
                  "weight_kg": 0,
                  "reps": 15,
                  "rep_range": null,
                  "distance_meters": null,
                  "duration_seconds": null,
                  "rpe": null,
                  "custom_metric": null
                }
              ]
            },
            {
              "exercise_template_id": "A41C7261",
              "superset_id": "B",
              "rest_seconds": 90,
              "notes": null,
              "sets": [
                {
                  "index": 0,
                  "type": "normal",
                  "weight_kg": 0,
                  "reps": 20,
                  "rep_range": null,
                  "distance_meters": null,
                  "duration_seconds": null,
                  "rpe": null,
                  "custom_metric": null
                },
                {
                  "index": 1,
                  "type": "normal",
                  "weight_kg": 0,
                  "reps": 20,
                  "rep_range": null,
                  "distance_meters": null,
                  "duration_seconds": null,
                  "rpe": null,
                  "custom_metric": null
                },
                {
                  "index": 2,
                  "type": "normal",
                  "weight_kg": 0,
                  "reps": 20,
                  "rep_range": null,
                  "distance_meters": null,
                  "duration_seconds": null,
                  "rpe": null,
                  "custom_metric": null
                }
              ]
            }
          ]
        },
        {
          "superset_id": "C",
          "section_type": "superset",
          "rounds": 1,
          "rest_between_rounds": 0,
          "target": "strength",
          "exercises": [
            {
              "exercise_template_id": "3601968B",
              "superset_id": "C",
              "rest_seconds": 0,
              "notes": null,
              "sets": [
                {
                  "index": 0,
                  "type": "normal",
                  "weight_kg": 20,
                  "reps": 12,
                  "rep_range": null,
                  "distance_meters": null,
                  "duration_seconds": null,
                  "rpe": null,
                  "custom_metric": null
                },
                {
                  "index": 1,
                  "type": "normal",
                  "weight_kg": 20,
                  "reps": 12,
                  "rep_range": null,
                  "distance_meters": null,
                  "duration_seconds": null,
                  "rpe": null,
                  "custom_metric": null
                },
                {
                  "index": 2,
                  "type": "normal",
                  "weight_kg": 20,
                  "reps": 12,
                  "rep_range": null,
                  "distance_meters": null,
                  "duration_seconds": null,
                  "rpe": null,
                  "custom_metric": null
                }
              ]
            },
            {
              "exercise_template_id": "37FCC2BB",
              "superset_id": "C",
              "rest_seconds": 0,
              "notes": null,
              "sets": [
                {
                  "index": 0,
                  "type": "normal",
                  "weight_kg": 10,
                  "reps": 15,
                  "rep_range": null,
                  "distance_meters": null,
                  "duration_seconds": null,
                  "rpe": null,
                  "custom_metric": null
                },
                {
                  "index": 1,
                  "type": "normal",
                  "weight_kg": 10,
                  "reps": 15,
                  "rep_range": null,
                  "distance_meters": null,
                  "duration_seconds": null,
                  "rpe": null,
                  "custom_metric": null
                },
                {
                  "index": 2,
                  "type": "normal",
                  "weight_kg": 10,
                  "reps": 15,
                  "rep_range": null,
                  "distance_meters": null,
                  "duration_seconds": null,
                  "rpe": null,
                  "custom_metric": null
                }
              ]
            },
            {
              "exercise_template_id": "BB792A36",
              "superset_id": "C",
              "rest_seconds": 90,
              "notes": null,
              "sets": [
                {
                  "index": 0,
                  "type": "normal",
                  "weight_kg": 0,
                  "reps": 10,
                  "rep_range": null,
                  "distance_meters": null,
                  "duration_seconds": null,
                  "rpe": null,
                  "custom_metric": null
                },
                {
                  "index": 1,
                  "type": "normal",
                  "weight_kg": 0,
                  "reps": 10,
                  "rep_range": null,
                  "distance_meters": null,
                  "duration_seconds": null,
                  "rpe": null,
                  "custom_metric": null
                },
                {
                  "index": 2,
                  "type": "normal",
                  "weight_kg": 0,
                  "reps": 10,
                  "rep_range": null,
                  "distance_meters": null,
                  "duration_seconds": null,
                  "rpe": null,
                  "custom_metric": null
                }
              ]
            }
          ]
        }
      ]
    }
  }
}
'''

# %%
with open("../hevy_folders.json", 'r') as f:
    folders_data = json.load(f)

# %%
routine = MonthlyWorkoutSchedule.model_validate_json(llm_response)

# %%
#routine.RoutinesByWeek["Week 1"].model_dump()

# %%
parse_pdf_to_json.save_routine(folders_data, routine, Path("../output"), parse_pdf_to_json.PDF_URLS[0][0])
# Out:
#   Saved to ../output/PaulSklarXfit365-Monthly-Program-v5/Week_1/Week_1.json
#   Saved to ../output/PaulSklarXfit365-Monthly-Program-v5/Week_2/Week_2.json
#   Saved to ../output/PaulSklarXfit365-Monthly-Program-v5/Week_3/Week_3.json
#   Saved to ../output/PaulSklarXfit365-Monthly-Program-v5/Week_4/Week_4.json
